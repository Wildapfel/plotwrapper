# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../../")

# %%
import pyplot as plt

# %%
fig, axs = plt.subplots()
axs[0][0].plot()

# %%
axs[0][0].dim_red_plot(None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 axs[0][0].dim_red_plot(None)
#
# File ~/HUB_local/projects/personal/programming/matplotlibw/tests/notebooks/../../data_viz/dim_red.py:20, in dim_red_plot(self, df, method)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/anaconda3/envs/ml-env/lib/python3.13/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...
